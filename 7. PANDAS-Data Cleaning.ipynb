# %%
lecture 38 was not good.
NaT not a time
Nan not a number
Data cleaning:-
    1.check null inputs/empty values/replace them with new value or remove them from data set.
    2.correcting incorrect format of any datatype like from string(object) to int.
    3.some time date is stored in string format.
    4.incorrect values/data in wrong coulmn.
    5.correcting duplicate values- same values in all rows and coulmns.

# %%
# !pip install pandas

# %%
import pandas

# %%
a=pandas.read_csv("E:\\DATA SCIENCE\\NOVEMBER\\dirtydata.csv")

# %%
a
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
a.info() # date type is object str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  107 non-null    int64
#  1   Date      106 non-null    object
#  2   Pulse     101 non-null    float64
#  3   Maxpulse  107 non-null    int64
#  4   Calories  105 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 4.3+ KB

# %%
 1.dropna removes : one complete row with null value -- check number 13 from original
 if pulse is given in range format 60-120
 if date is in object/str form
 if time is in wrong.45 is 450 mistakenly
 if two rows have same data 11 - 12 
 remove or replace with correct value.

# %%
a.dropna().head(15)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0

# %%
-- replace null value with

dropna-- to remove null values
fillna-- to replace null values

# %%
a.fillna('no data').sample(5)
# Out:
#      Duration          Date  Pulse  Maxpulse Calories
# 42         60  '2020/12/11'  103.0       147    329.3
# 103        60  '2020/12/12'  100.0       120    250.7
# 94         60  '2020/12/03'  103.0       135    340.0
# 97         60  '2020/12/06'  102.0       127    300.0
# 17         60  '2020/12/17'  100.0       120    300.0

# %%
a
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
-- relpacing coulmn wise()
use dropna subset

inplace=True means to save the change in the sAME data set
inplace=Flase means to save the change in the new dataset or vairable

# %%
a.dropna[subset = ['Pulse','Calories'],inplace=True,axis=1]

# %%
a.drop[subset = ['Pulse','Calories'],inplace=True,axis=1]

# %%
a['Pulse'].fillna('no pulse saved').sample(5)
# Out:
# 62             110.0
# 12             100.0
# 48             117.0
# 75    no pulse saved
# 3              109.0
# Name: Pulse, dtype: object

# %%
-- mean mode median coulmn wise

# %%
a['Pulse'].mean()
# Out:
# 105.3069306930693

# %%
a['Maxpulse'].mode()
# Out:
# 0    120
# Name: Maxpulse, dtype: int64

# %%
a['Maxpulse'].median()
# Out:
# 132.0

# %%
-- as date is in str format change it to int/date

# %%
a.info() # date type is object str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  107 non-null    int64
#  1   Date      106 non-null    object
#  2   Pulse     101 non-null    float64
#  3   Maxpulse  107 non-null    int64
#  4   Calories  105 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 4.3+ KB

# %%
a['Date']=pandas.to_datetime(a['Date'])

# %%
a.sample(5)
# look output date was object which was changed to datetime format
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 2         60 2020-12-03  103.0       135     340.0
# 89        60 2020-12-12  100.0       120     250.7
# 13        60 2020-12-13    NaN       128     345.3
# 68        60 2020-12-07  110.0       136     374.0
# 27        60 2020-12-27   92.0       118     241.0

# %%
-- duplicate values

# %%
a.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 102     True
# 103     True
# 104     True
# 105     True
# 106     True
# Length: 107, dtype: bool

# %%
a.drop_duplicates() # check 11 and 12   row wise
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01  110.0       130     409.1
# 1         60 2020-12-02  117.0       145     479.0
# 2         60 2020-12-03  103.0       135     340.0
# 3         45 2020-12-04  109.0       175     282.4
# 4         45 2020-12-05  117.0       148     406.0
# 5         60 2020-12-06  102.0       127     300.0
# 6         60 2020-12-07  110.0       136     374.0
# 7        450 2020-12-08  104.0       134     253.3
# 8         30 2020-12-09  109.0       133     195.1
# 9         60 2020-12-10   98.0       124     269.0
# 10        60 2020-12-11  103.0       147     329.3
# 11        60 2020-12-12  100.0       120     250.7
# 13        60 2020-12-13    NaN       128     345.3
# 14        60 2020-12-14  104.0       132     379.3
# 15        60 2020-12-15   98.0       123     275.0
# 16        60 2020-12-16   98.0       120     215.2
# 17        60 2020-12-17  100.0       120     300.0
# ...

# %%
-- to find location

# %%
a.loc[5:9]
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 5        60 2020-12-06  102.0       127     300.0
# 6        60 2020-12-07  110.0       136     374.0
# 7       450 2020-12-08  104.0       134     253.3
# 8        30 2020-12-09  109.0       133     195.1
# 9        60 2020-12-10   98.0       124     269.0

# %%
a.loc[5]
# Out:
# Duration                     60
# Date        2020-12-06 00:00:00
# Pulse                     102.0
# Maxpulse                    127
# Calories                  300.0
# Name: 5, dtype: object

# %%
loc/iloc?? check difrrence

# %%
a.iloc[5:9]
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 5        60 2020-12-06  102.0       127     300.0
# 6        60 2020-12-07  110.0       136     374.0
# 7       450 2020-12-08  104.0       134     253.3
# 8        30 2020-12-09  109.0       133     195.1

# %%
replacing using loc-- chnaging 450 mins to 45 at 7 index

# %%
a.loc[7,'Duration']
# Out:
# 450

# %%
a.loc[7,'Duration']=45

# %%
a.loc[7,'Duration']
# Out:
# 45

# %%
a.loc[7]
# Out:
# Duration                     45
# Date        2020-12-08 00:00:00
# Pulse                     104.0
# Maxpulse                    134
# Calories                  253.3
# Name: 7, dtype: object

# %%
a.head(8)
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01  110.0       130     409.1
# 1        60 2020-12-02  117.0       145     479.0
# 2        60 2020-12-03  103.0       135     340.0
# 3        45 2020-12-04  109.0       175     282.4
# 4        45 2020-12-05  117.0       148     406.0
# 5        60 2020-12-06  102.0       127     300.0
# 6        60 2020-12-07  110.0       136     374.0
# 7        45 2020-12-08  104.0       134     253.3

# %%
relacing using replacement

# %%
a['Duration'].replace(60,45).sample(5)
# Out:
# 63    45
# 40    30
# 80    45
# 27    45
# 37    45
# Name: Duration, dtype: int64

# %%
drop coulmn wise

# %%
a.reset_index(inplace=True)
a
# Out:
#      index  Duration       Date  Pulse  Maxpulse  Calories
# 0        0        60 2020-12-01  110.0       130     409.1
# 1        1        60 2020-12-02  117.0       145     479.0
# 2        2        60 2020-12-03  103.0       135     340.0
# 3        3        45 2020-12-04  109.0       175     282.4
# 4        4        45 2020-12-05  117.0       148     406.0
# ..     ...       ...        ...    ...       ...       ...
# 102    102        60 2020-12-11  103.0       147     329.3
# 103    103        60 2020-12-12  100.0       120     250.7
# 104    104        60 2020-12-12  100.0       120     250.7
# 105    105        60 2020-12-13    NaN       128     345.3
# 106    106        60 2020-12-14  104.0       132     379.3
#
# [107 rows x 6 columns]

# %%
a.drop(['index'],axis=1)
# Out:
#      Duration       Date  Pulse  Maxpulse  Calories
# 0          60 2020-12-01  110.0       130     409.1
# 1          60 2020-12-02  117.0       145     479.0
# 2          60 2020-12-03  103.0       135     340.0
# 3          45 2020-12-04  109.0       175     282.4
# 4          45 2020-12-05  117.0       148     406.0
# ..        ...        ...    ...       ...       ...
# 102        60 2020-12-11  103.0       147     329.3
# 103        60 2020-12-12  100.0       120     250.7
# 104        60 2020-12-12  100.0       120     250.7
# 105        60 2020-12-13    NaN       128     345.3
# 106        60 2020-12-14  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
to convert a dataset into numoy
a.to_numpy()

# %%
a1=a.to_numpy()

# %%
a1
# Out:
# array([[0, 60, Timestamp('2020-12-01 00:00:00'), 110.0, 130, 409.1],
#        [1, 60, Timestamp('2020-12-02 00:00:00'), 117.0, 145, 479.0],
#        [2, 60, Timestamp('2020-12-03 00:00:00'), 103.0, 135, 340.0],
#        [3, 45, Timestamp('2020-12-04 00:00:00'), 109.0, 175, 282.4],
#        [4, 45, Timestamp('2020-12-05 00:00:00'), 117.0, 148, 406.0],
#        [5, 60, Timestamp('2020-12-06 00:00:00'), 102.0, 127, 300.0],
#        [6, 60, Timestamp('2020-12-07 00:00:00'), 110.0, 136, 374.0],
#        [7, 45, Timestamp('2020-12-08 00:00:00'), 104.0, 134, 253.3],
#        [8, 30, Timestamp('2020-12-09 00:00:00'), 109.0, 133, 195.1],
#        [9, 60, Timestamp('2020-12-10 00:00:00'), 98.0, 124, 269.0],
#        [10, 60, Timestamp('2020-12-11 00:00:00'), 103.0, 147, 329.3],
#        [11, 60, Timestamp('2020-12-12 00:00:00'), 100.0, 120, 250.7],
#        [12, 60, Timestamp('2020-12-12 00:00:00'), 100.0, 120, 250.7],
#        [13, 60, Timestamp('2020-12-13 00:00:00'), nan, 128, 345.3],
# ...
