# %%
PANDAS is library used for structed data which cant not be used in array.
converting SQL table into excelsheet.sorting,understanding database of sql table or
excelsheet which is in row coulmn format.HERE list.dict are unstructred data 
so use pandas to convert them into structred one.
   
TWO TYPES DATA:
    STRUCTERED DATA HAVE ROWS AND COLUMNS.
    UNSTRUCTERED DATA ARE IN PARA FORMAT,pdf file,notepad,wordfile.

-- in pandas   
1.Dataframe:multiple coulmns (in excel file.)
2.Series:single coulmns information 

multiple series can be added to make one dataframe.
single series can be derives from a dataframe.

NUMPY LIB-- array datatype used in it.any sample is in array form. mathematical operation on array


NaN is not a number.

# %%
# !pip install pandas

# %%
import pandas

# %%
1.create a vairable to store excel file or csv file.

csv file full form/xlxs -- file use double \\to avoid error while importing file

# %%
a=pandas.read_csv("C:\\Users\\Comp\\Desktop\\DATA SCIENCE\\NOVEMBER\\indian_state.csv")

# %%
a
# Out:
#     Index_No           STATE_UT STATE_ FORMED_YEAR  \
# 0          1  Jammu and Kashmir         2019-10-31
# 1          2              Delhi         1956-11-01
# 2          3        Maharashtra         1960-05-01
# 3          4           Nagaland         1963-05-01
# 4          5             Punjab         1947-10-01
# 5          6             Sikkim         1975-05-16
# 6          7         Tamil Nadu         1956-11-01
# 7          8        Lakshadweep         1956-11-01
# 8          9            Haryana         1966-11-01
# 9         10            GUJARAT                NaN
# 10        15                abc                NaN
# 11        18                xyz                NaN
# 12        19           bhfhbjvf                NaN
# 13        20               XYZ1         1985-05-25
#
#                               CAPITAL  Num.of_Distric          Local_Language
# 0   Srinagar (Summer), Jammu (Winter)            20.0  Kashmiri, Hindi, Dogri
# ...

# %%
type(a) # type is dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
a.shape # 14 R 6 C
# Out:
# (14, 6)

# %%
a.ndim
# Out:
# 2

# %%
a.all()
# Out:
# Index_No              True
# STATE_UT              True
# STATE_ FORMED_YEAR    True
# CAPITAL               True
# Num.of_Distric        True
# Local_Language        True
# dtype: bool

# %%
to check string(object),int,float in a dataset,, to check missing data if any

# %%
a.info() # string type data is called as object.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index_No            14 non-null     int64
#  1   STATE_UT            14 non-null     object
#  2   STATE_ FORMED_YEAR  10 non-null     object
#  3   CAPITAL             14 non-null     object
#  4   Num.of_Distric      10 non-null     float64
#  5   Local_Language      14 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 800.0+ bytes

# %%
a.infer_objects()
# Out:
#     Index_No           STATE_UT STATE_ FORMED_YEAR  \
# 0          1  Jammu and Kashmir         2019-10-31
# 1          2              Delhi         1956-11-01
# 2          3        Maharashtra         1960-05-01
# 3          4           Nagaland         1963-05-01
# 4          5             Punjab         1947-10-01
# 5          6             Sikkim         1975-05-16
# 6          7         Tamil Nadu         1956-11-01
# 7          8        Lakshadweep         1956-11-01
# 8          9            Haryana         1966-11-01
# 9         10            GUJARAT                NaN
# 10        15                abc                NaN
# 11        18                xyz                NaN
# 12        19           bhfhbjvf                NaN
# 13        20               XYZ1         1985-05-25
#
#                               CAPITAL  Num.of_Distric          Local_Language
# 0   Srinagar (Summer), Jammu (Winter)            20.0  Kashmiri, Hindi, Dogri
# ...

# %%
b=pandas.read_csv("C:\\Users\\Comp\\Desktop\\DATA SCIENCE\\NOVEMBER\\dirtydata.csv")

# %%
b # max shows only 99 values else it shows only first 5 values and last 5 values.
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
b.head() # gives output first 5 data as default
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'  110.0       130     409.1
# 1        60  '2020/12/02'  117.0       145     479.0
# 2        60  '2020/12/03'  103.0       135     340.0
# 3        45  '2020/12/04'  109.0       175     282.4
# 4        45  '2020/12/05'  117.0       148     406.0

# %%
b.head(9)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'  110.0       130     409.1
# 1        60  '2020/12/02'  117.0       145     479.0
# 2        60  '2020/12/03'  103.0       135     340.0
# 3        45  '2020/12/04'  109.0       175     282.4
# 4        45  '2020/12/05'  117.0       148     406.0
# 5        60  '2020/12/06'  102.0       127     300.0
# 6        60  '2020/12/07'  110.0       136     374.0
# 7       450  '2020/12/08'  104.0       134     253.3
# 8        30  '2020/12/09'  109.0       133     195.1

# %%
b.tail() # default shows last 5
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3

# %%
b.tail(2)
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3

# %% [raw]
# -- to check random values and not sequwncw wise

# %%
b.sample() # gives any random values
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 59        60  '2020/12/12'  100.0       120     250.7

# %%
b.sample(5) # gives random 5 values
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 102        60  '2020/12/11'  103.0       147     329.3
# 3          45  '2020/12/04'  109.0       175     282.4
# 16         60  '2020/12/16'   98.0       120     215.2
# 94         60  '2020/12/03'  103.0       135     340.0
# 30         60  '2020/12/30'  102.0       129     380.3

# %%
a[2:7]
# Out:
#    Index_No     STATE_UT STATE_ FORMED_YEAR     CAPITAL  Num.of_Distric  \
# 2         3  Maharashtra         1960-05-01      Mumbai            36.0
# 3         4     Nagaland         1963-05-01      Kohima            16.0
# 4         5       Punjab         1947-10-01  Chandigarh            23.0
# 5         6       Sikkim         1975-05-16     Gangtok             6.0
# 6         7   Tamil Nadu         1956-11-01     Chennai            38.0
#
#      Local_Language
# 2           Marathi
# 3  Konyak, Ao, Sema
# 4           Punjabi
# 5            Nepali
# 6             Tamil

# %%
b[:5]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'  110.0       130     409.1
# 1        60  '2020/12/02'  117.0       145     479.0
# 2        60  '2020/12/03'  103.0       135     340.0
# 3        45  '2020/12/04'  109.0       175     282.4
# 4        45  '2020/12/05'  117.0       148     406.0

# %%
b[5:7]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 5        60  '2020/12/06'  102.0       127     300.0
# 6        60  '2020/12/07'  110.0       136     374.0

# %% [raw]
# to get last sample coulumn of   dataset  using slicing

# %%
b[:5,:15] # this option does not work for dataframe in pandas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, 5, None), slice(None, 15, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 b[:5,:15]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
# ...

# %%
dic={"Student name":["X","Y","Z","A","B","C"],"status":["pass",'fail','pass','fail',"pass",'pass']}

# %%
a=pandas.DataFrame(dic) # converted unstrutred dic into structed data using pandas

# %%
a
# Out:
#   Student name status
# 0            X   pass
# 1            Y   fail
# 2            Z   pass
# 3            A   fail
# 4            B   pass
# 5            C   pass

# %%
to give index to a

# %%
a=pandas.DataFrame(dic)
#a=pandas.DataFrame(dic,index=[1,2,3,4,5,6])

# %%
a
# Out:
#   Student name status
# 0            X   pass
# 1            Y   fail
# 2            Z   pass
# 3            A   fail
# 4            B   pass
# 5            C   pass

# %%
a=pandas.DataFrame(dic,index=[1,2,3,4,5,6])
a
# Out:
#   Student name status
# 1            X   pass
# 2            Y   fail
# 3            Z   pass
# 4            A   fail
# 5            B   pass
# 6            C   pass

# %%
to add new coulmn in a dataset?

# %%
list

# %%
address=["dighi",'mumbai','ooty','pune','goa','mumbai']

# %%
a1=pandas.Series(address,name='address')

# %%
a1
# Out:
# 0     dighi
# 1    mumbai
# 2      ooty
# 3      pune
# 4       goa
# 5    mumbai
# Name: address, dtype: object

# %%
type(a1)
# Out:
# pandas.core.series.Series

# %%
to add new coulmn in a dataset of student table?

# %%
a=pandas.concat([a,a1],axis=1)

# %%
a
# Out:
#   Student name status address
# 0            X   pass   dighi
# 1            Y   fail  mumbai
# 2            Z   pass    ooty
# 3            A   fail    pune
# 4            B   pass     goa
# 5            C   pass  mumbai

# %%
-- isnull shows where the null is present

# %%
b.isnull()  #shows true where null is present.. and false null is not
# Out:
#      Duration   Date  Pulse  Maxpulse  Calories
# 0       False  False  False     False     False
# 1       False  False  False     False     False
# 2       False  False  False     False     False
# 3       False  False  False     False     False
# 4       False  False  False     False     False
# ..        ...    ...    ...       ...       ...
# 102     False  False  False     False     False
# 103     False  False  False     False     False
# 104     False  False  False     False     False
# 105     False  False   True     False     False
# 106     False  False  False     False     False
#
# [107 rows x 5 columns]

# %%
-- to show total count of null values in each coulmn.

# %%
b.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       6
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
-- describe showa coulmn with int and float value only

# %%
b.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count  107.000000  101.000000  107.000000  105.000000
# mean    77.943925  105.306931  133.476636  318.632381
# std     91.483974    6.635876   13.745219   72.350692
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  124.000000  253.300000
# 50%     60.000000  104.000000  132.000000  300.000000
# 75%     60.000000  109.000000  136.000000  374.000000
# max    450.000000  130.000000  175.000000  479.000000

# %%
-- use dropna to remove all null cell,, works row wise

# %%
b.dropna()
b
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
b
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
-- drop null from any particlar value

# %%
b.dropna(subset=['Pulse','Date','Calories'])
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 101        60  '2020/12/10'   98.0       124     269.0
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [98 rows x 5 columns]

# %%
-- use inplace method to save dataset from in itself or in new using vairable
inplace default is false.
False: 
True:new updated dataset saved in itself only.

# %%
a
# Out:
#     Index_No           STATE_UT STATE_ FORMED_YEAR  \
# 0          1  Jammu and Kashmir         2019-10-31
# 1          2              Delhi         1956-11-01
# 2          3        Maharashtra         1960-05-01
# 3          4           Nagaland         1963-05-01
# 4          5             Punjab         1947-10-01
# 5          6             Sikkim         1975-05-16
# 6          7         Tamil Nadu         1956-11-01
# 7          8        Lakshadweep         1956-11-01
# 8          9            Haryana         1966-11-01
# 9         10            GUJARAT                NaN
# 10        15                abc                NaN
# 11        18                xyz                NaN
# 12        19           bhfhbjvf                NaN
# 13        20               XYZ1         1985-05-25
#
#                               CAPITAL  Num.of_Distric          Local_Language
# 0   Srinagar (Summer), Jammu (Winter)            20.0  Kashmiri, Hindi, Dogri
# ...

# %%
a1=a.dropna(subset=['STATE_ FORMED_YEAR'],inplace = False)
a1
# Out:
#     Index_No           STATE_UT STATE_ FORMED_YEAR  \
# 0          1  Jammu and Kashmir         2019-10-31
# 1          2              Delhi         1956-11-01
# 2          3        Maharashtra         1960-05-01
# 3          4           Nagaland         1963-05-01
# 4          5             Punjab         1947-10-01
# 5          6             Sikkim         1975-05-16
# 6          7         Tamil Nadu         1956-11-01
# 7          8        Lakshadweep         1956-11-01
# 8          9            Haryana         1966-11-01
# 13        20               XYZ1         1985-05-25
#
#                               CAPITAL  Num.of_Distric          Local_Language
# 0   Srinagar (Summer), Jammu (Winter)            20.0  Kashmiri, Hindi, Dogri
# 1                           New Delhi            11.0                   Hindi
# 2                              Mumbai            36.0                 Marathi
# 3                              Kohima            16.0        Konyak, Ao, Sema
# ...

# %%
a2=a.dropna(subset=['STATE_ FORMED_YEAR'],inplace = True)
a2

# %%
-- to remove whole coulmn from any dataset

# %%
b
# Out:
#      Duration          Date  Pulse  Maxpulse  Calories
# 0          60  '2020/12/01'  110.0       130     409.1
# 1          60  '2020/12/02'  117.0       145     479.0
# 2          60  '2020/12/03'  103.0       135     340.0
# 3          45  '2020/12/04'  109.0       175     282.4
# 4          45  '2020/12/05'  117.0       148     406.0
# ..        ...           ...    ...       ...       ...
# 102        60  '2020/12/11'  103.0       147     329.3
# 103        60  '2020/12/12'  100.0       120     250.7
# 104        60  '2020/12/12'  100.0       120     250.7
# 105        60  '2020/12/13'    NaN       128     345.3
# 106        60  '2020/12/14'  104.0       132     379.3
#
# [107 rows x 5 columns]

# %%
b.drop(['Date'],axis=1,inplace=True) # mention coulmn name

# %%
b
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60  110.0       130     409.1
# 1          60  117.0       145     479.0
# 2          60  103.0       135     340.0
# 3          45  109.0       175     282.4
# 4          45  117.0       148     406.0
# ..        ...    ...       ...       ...
# 102        60  103.0       147     329.3
# 103        60  100.0       120     250.7
# 104        60  100.0       120     250.7
# 105        60    NaN       128     345.3
# 106        60  104.0       132     379.3
#
# [107 rows x 4 columns]

# %%
-- to add new "common" coulmn to dataset

# %%
a
# Out:
#   Student name status
# 1            X   pass
# 2            Y   fail
# 3            Z   pass
# 4            A   fail
# 5            B   pass
# 6            C   pass

# %%
a['pass out year'] = 2022

# %%
a
# Out:
#   Student name status  pass out year
# 1            X   pass           2022
# 2            Y   fail           2022
# 3            Z   pass           2022
# 4            A   fail           2022
# 5            B   pass           2022
# 6            C   pass           2022

# %%
-- to get one coulmn from dataset

# %%
a['status']
# Out:
# 1    pass
# 2    fail
# 3    pass
# 4    fail
# 5    pass
# 6    pass
# Name: status, dtype: object

# %%
a.shape
# Out:
# (6, 3)
